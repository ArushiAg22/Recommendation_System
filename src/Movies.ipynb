# %%
import pandas as pd

# %%
movies = pd.read_csv("/Users/arushiagarwal/Downloads/movies 3.csv")
movies
# Out:
#             id                              title  \
# 0       615656                  Meg 2: The Trench
# 1       758323                The Pope's Exorcist
# 2       667538   Transformers: Rise of the Beasts
# 3       640146  Ant-Man and the Wasp: Quantumania
# 4       677179                          Creed III
# ...        ...                                ...
# 722705  149339             The Wild and the Brave
# 722706  633623                      Midsommarvaka
# 722707  423027     Creature from under the Bridge
# 722708  499883                        The Killers
# 722709  968161                      Gising Sining
#
#                                   genres original_language  \
# 0          Action-Science Fiction-Horror                en
# 1                Horror-Mystery-Thriller                en
# 2       Action-Adventure-Science Fiction                en
# 3       Action-Adventure-Science Fiction                en
# 4                           Drama-Action                en
# ...

# %%
movies.shape
# Out:
# (722710, 20)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722710 entries, 0 to 722709
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    722710 non-null  int64
#  1   title                 722706 non-null  object
#  2   genres                511966 non-null  object
#  3   original_language     722710 non-null  object
#  4   overview              604173 non-null  object
#  5   popularity            722710 non-null  float64
#  6   production_companies  337210 non-null  object
#  7   release_date          670482 non-null  object
#  8   budget                722710 non-null  float64
#  9   revenue               722710 non-null  float64
#  10  runtime               688279 non-null  float64
#  11  status                722710 non-null  object
#  12  tagline               108175 non-null  object
#  13  vote_average          722710 non-null  float64
# ...

# %%
movies.describe()
# Out:
#                   id     popularity        budget       revenue       runtime  \
# count  722710.000000  722710.000000  7.227100e+05  7.227100e+05  6.882790e+05
# mean   526920.326850       1.820676  3.943883e+05  9.835544e+05  1.989543e+02
# std    253173.107075      20.622920  8.146660e+06  2.019755e+07  8.582405e+04
# min         2.000000       0.600000  0.000000e+00 -1.200000e+01  0.000000e+00
# 25%    328938.250000       0.600000  0.000000e+00  0.000000e+00  5.000000e+00
# 50%    533367.000000       0.600000  0.000000e+00  0.000000e+00  5.000000e+01
# 75%    737830.000000       1.293000  0.000000e+00  0.000000e+00  9.000000e+01
# max    968161.000000    8763.998000  5.000000e+09  2.920357e+09  5.050505e+07
#
#         vote_average     vote_count
# count  722710.000000  722710.000000
# mean        2.443909      27.722071
# std         3.175834     383.354907
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# ...

# %%
movies["status"].value_counts()
# Out:
# Released           716829
# Planned              2658
# In Production        1565
# Post Production      1253
# Canceled              233
# Rumored               172
# Name: status, dtype: int64

# %%
movies["original_language"].value_counts()
# Out:
# en    379288
# fr     44807
# es     42403
# de     37081
# ja     27692
#        ...
# tn         1
# cv         1
# fj         1
# ia         1
# rn         1
# Name: original_language, Length: 167, dtype: int64

# %%
movies["genres"].value_counts()
# Out:
# Documentary                                        95081
# Drama                                              80104
# Comedy                                             46906
# Animation                                          22336
# Music                                              17926
#                                                    ...
# Comedy-Animation-Fantasy-Action-Science Fiction        1
# Drama-Thriller-Action-TV Movie                         1
# Romance-Thriller-Horror-Crime-Mystery-Drama            1
# TV Movie-Comedy-Drama-Family-Romance                   1
# Science Fiction-Mystery-Drama-Thriller                 1
# Name: genres, Length: 11028, dtype: int64

# %%
movies.isnull().sum()
# Out:
# id                           0
# title                        4
# genres                  210744
# original_language            0
# overview                118537
# popularity                   0
# production_companies    385500
# release_date             52228
# budget                       0
# revenue                      0
# runtime                  34431
# status                       0
# tagline                 614535
# vote_average                 0
# vote_count                   0
# credits                 225026
# keywords                512361
# poster_path             185069
# backdrop_path           500037
# recommendations         687925
# dtype: int64
